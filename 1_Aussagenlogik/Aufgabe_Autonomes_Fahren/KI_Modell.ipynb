# %%
from wissensbasis import *

# %%
# Create the knowledge base
wb = erstelle_wissensbasis()

# Example of a combination - create F and get its negation
F_neg = Negation(AtomareFormel("F"))
print(F_neg)

# Geben bakannte Fakten ein
bekannte_fakten = {AtomareFormel("N")}  # Angenommen, N ist wahr

# Apply Modus Ponens
inferenz = wende_modus_ponens_an(wb, bekannte_fakten)
print("Abgeleitete Fakten:", inferenz)
# Out:
# ¬F
# Modus Ponens ausgeführt: N → I
# Modus Ponens ausgeführt: I → S
# Abgeleitete Fakten: {'I', 'N', 'S'}
